# %%
# display some images for every different expression

import numpy as np
import seaborn as sns
from tensorflow import keras
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import matplotlib.pyplot as plt
import os

# size of the image: 48*48 pixels
pic_size = 48

# input path for the images
from google.colab import drive 
drive.mount('/content/drive')
base_path = '/content/drive/My Drive/Colab Notebooks/images/'

plt.figure(0, figsize=(12,20))
cpt = 0

for expression in os.listdir(base_path + "train"):
    for i in range(1,6):
        cpt = cpt + 1
        plt.subplot(7,5,cpt)
        img = load_img(base_path + "train/" + expression + "/" +os.listdir(base_path + "train/" + expression)[i], target_size=(pic_size, pic_size))
        plt.imshow(img, cmap="gray")

plt.tight_layout()
plt.show()
# Out:
# Mounted at /content/drive

# %%
# building data generator 

from keras.preprocessing.image import ImageDataGenerator

batch_size = 128
# base_path = "../input/face-expression-recognition-dataset/images/"


train_datagen = ImageDataGenerator(rescale = 1.0/255.0,
                                  width_shift_range = 0.1,
                                   height_shift_range = 0.1,
                                   rotation_range = 20,
                                   horizontal_flip = True)

validation_datagen = ImageDataGenerator(rescale= 1.0/255)

train_generator = train_datagen.flow_from_directory(base_path + "train",
                                                    target_size=(56,56),
                                                    color_mode="grayscale",
                                                    batch_size=batch_size,
                                                    class_mode='categorical',
                                                    shuffle=True)

validation_generator = validation_datagen.flow_from_directory(base_path + "validation",
                                                    target_size=(56,56),
                                                    color_mode="grayscale",
                                                    batch_size=batch_size,
                                                    class_mode='categorical',
                                                    shuffle=False)
# Out:
# Found 3395 images belonging to 7 classes.
# Found 427 images belonging to 7 classes.

# %%
from keras.layers import Dense, Input, Dropout, GlobalAveragePooling2D, Flatten, Conv2D, BatchNormalization, Activation, MaxPooling2D
from keras.models import Model, Sequential
from keras.optimizers import Adam

# number of possible label values
nb_classes = 7

# Initialising the CNN
model = Sequential()

# 1 - Convolution
model.add(Conv2D(64,(3,3), padding='same', input_shape=(56, 56,1)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# 2nd Convolution layer
model.add(Conv2D(128,(5,5), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# 3rd Convolution layer
model.add(Conv2D(512,(3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# 4th Convolution layer
model.add(Conv2D(512,(3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# Flattening
model.add(Flatten())

# Fully connected layer 1st layer
model.add(Dense(256))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.25))

# Fully connected layer 2nd layer
model.add(Dense(512))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.25))

model.add(Dense(nb_classes, activation='softmax'))

print(model.summary())

opt = Adam(lr=0.0005)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 56, 56, 64)        640
#
#  batch_normalization (BatchN  (None, 56, 56, 64)       256
#  ormalization)
#
#  activation (Activation)     (None, 56, 56, 64)        0
#
#  max_pooling2d (MaxPooling2D  (None, 28, 28, 64)       0
#  )
#
#  dropout (Dropout)           (None, 28, 28, 64)        0
#
#  conv2d_1 (Conv2D)           (None, 28, 28, 128)       204928
#
#  batch_normalization_1 (Batc  (None, 28, 28, 128)      512
#  hNormalization)
#
#  activation_1 (Activation)   (None, 28, 28, 128)       0
#
#  max_pooling2d_1 (MaxPooling  (None, 14, 14, 128)      0
#  2D)
#
#  dropout_1 (Dropout)         (None, 14, 14, 128)       0
#
#  conv2d_2 (Conv2D)           (None, 14, 14, 512)       590336
#
#  batch_normalization_2 (Batc  (None, 14, 14, 512)      2048
#  hNormalization)
#
#  activation_2 (Activation)   (None, 14, 14, 512)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 7, 7, 512)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 7, 7, 512)         0
#
#  conv2d_3 (Conv2D)           (None, 7, 7, 512)         2359808
#
#  batch_normalization_3 (Batc  (None, 7, 7, 512)        2048
#  hNormalization)
#
#  activation_3 (Activation)   (None, 7, 7, 512)         0
#
#  max_pooling2d_3 (MaxPooling  (None, 3, 3, 512)        0
#  2D)
#
#  dropout_3 (Dropout)         (None, 3, 3, 512)         0
#
#  flatten (Flatten)           (None, 4608)              0
#
#  dense (Dense)               (None, 256)               1179904
#
#  batch_normalization_4 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation_4 (Activation)   (None, 256)               0
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 512)               131584
#
#  batch_normalization_5 (Batc  (None, 512)              2048
#  hNormalization)
#
#  activation_5 (Activation)   (None, 512)               0
#
#  dropout_5 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 7)                 3591
#
# =================================================================
# Total params: 4,478,727
# Trainable params: 4,474,759
# Non-trainable params: 3,968
# _________________________________________________________________
# None
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
# %%time

# number of epochs to train the NN
epochs = 500
# checkpoint to save best model
from keras.callbacks import ModelCheckpoint

checkpoint = ModelCheckpoint('/content/drive/My Drive/Colab Notebooks/input/model_weights.h5', monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

history = model.fit_generator(generator=train_generator,
                                steps_per_epoch=train_generator.n//train_generator.batch_size,
                                epochs=epochs,
                                validation_data = validation_generator,
                                validation_steps = validation_generator.n//validation_generator.batch_size,
                                callbacks=callbacks_list
                                )
# Out:
# <timed exec>:9: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Epoch 1/500
# 26/26 [==============================] - ETA: 0s - loss: 2.2255 - accuracy: 0.1696
# Epoch 1: val_accuracy improved from -inf to 0.14583, saving model to /content/drive/My Drive/Colab Notebooks/input/model_weights.h5
# 26/26 [==============================] - 322s 12s/step - loss: 2.2255 - accuracy: 0.1696 - val_loss: 1.9410 - val_accuracy: 0.1458
# Epoch 2/500
# 26/26 [==============================] - ETA: 0s - loss: 2.1381 - accuracy: 0.1766
# Epoch 2: val_accuracy did not improve from 0.14583
# 26/26 [==============================] - 7s 283ms/step - loss: 2.1381 - accuracy: 0.1766 - val_loss: 1.9471 - val_accuracy: 0.1458
# Epoch 3/500
# 26/26 [==============================] - ETA: 0s - loss: 2.0781 - accuracy: 0.1941
# Epoch 3: val_accuracy improved from 0.14583 to 0.15885, saving model to /content/drive/My Drive/Colab Notebooks/input/model_weights.h5
# 26/26 [==============================] - 9s 348ms/step - loss: 2.0781 - accuracy: 0.1941 - val_loss: 1.9825 - val_accuracy: 0.1589
# Epoch 4/500
# 26/26 [==============================] - ETA: 0s - loss: 2.0380 - accuracy: 0.2002
# Epoch 4: val_accuracy did not improve from 0.15885
# 26/26 [==============================] - 7s 283ms/step - loss: 2.0380 - accuracy: 0.2002 - val_loss: 2.0196 - val_accuracy: 0.1589
# Epoch 5/500
# 26/26 [==============================] - ETA: 0s - loss: 2.0202 - accuracy: 0.2100
# Epoch 5: val_accuracy did not improve from 0.15885
# 26/26 [==============================] - 7s 286ms/step - loss: 2.0202 - accuracy: 0.2100 - val_loss: 2.0301 - val_accuracy: 0.1589
# Epoch 6/500
# 26/26 [==============================] - ETA: 0s - loss: 2.0240 - accuracy: 0.2023
# Epoch 6: val_accuracy improved from 0.15885 to 0.16146, saving model to /content/drive/My Drive/Colab Notebooks/input/model_weights.h5
# 26/26 [==============================] - 9s 333ms/step - loss: 2.0240 - accuracy: 0.2023 - val_loss: 2.0050 - val_accuracy: 0.1615
# Epoch 7/500
# 26/26 [==============================] - ETA: 0s - loss: 1.9814 - accuracy: 0.2164
# Epoch 7: val_accuracy did not improve from 0.16146
# 26/26 [==============================] - 7s 279ms/step - loss: 1.9814 - accuracy: 0.2164 - val_loss: 2.1236 - val_accuracy: 0.1615
# Epoch 8/500
# 26/26 [==============================] - ETA: 0s - loss: 1.9511 - accuracy: 0.2412
# Epoch 8: val_accuracy did not improve from 0.16146
# 26/26 [==============================] - 7s 281ms/step - loss: 1.9511 - accuracy: 0.2412 - val_loss: 2.0968 - val_accuracy: 0.1589
# Epoch 9/500
# 26/26 [==============================] - ETA: 0s - loss: 1.9215 - accuracy: 0.2485
# Epoch 9: val_accuracy did not improve from 0.16146
# 26/26 [==============================] - 7s 276ms/step - loss: 1.9215 - accuracy: 0.2485 - val_loss: 2.1712 - val_accuracy: 0.1589
# Epoch 10/500
# 26/26 [==============================] - ETA: 0s - loss: 1.9091 - accuracy: 0.2495
# Epoch 10: val_accuracy improved from 0.16146 to 0.17708, saving model to /content/drive/My Drive/Colab Notebooks/input/model_weights.h5
# 26/26 [==============================] - 9s 329ms/step - loss: 1.9091 - accuracy: 0.2495 - val_loss: 2.2952 - val_accuracy: 0.1771
# Epoch 11/500
# 26/26 [==============================] - ETA: 0s - loss: 1.8780 - accuracy: 0.2632
# Epoch 11: val_accuracy did not improve from 0.17708
# 26/26 [==============================] - 7s 280ms/step - loss: 1.8780 - accuracy: 0.2632 - val_loss: 2.3282 - val_accuracy: 0.1667
# Epoch 12/500
# 26/26 [==============================] - ETA: 0s - loss: 1.8653 - accuracy: 0.2807
# Epoch 12: val_accuracy did not improve from 0.17708
# 26/26 [==============================] - 7s 282ms/step - loss: 1.8653 - accuracy: 0.2807 - val_loss: 2.2706 - val_accuracy: 0.1589
# Epoch 13/500
# 26/26 [==============================] - ETA: 0s - loss: 1.8430 - accuracy: 0.2773
# Epoch 13: val_accuracy improved from 0.17708 to 0.17969, saving model to /content/drive/My Drive/Colab Notebooks/input/model_weights.h5
# 26/26 [==============================] - 9s 354ms/step - loss: 1.8430 - accuracy: 0.2773 - val_loss: 2.2156 - val_accuracy: 0.1797
# Epoch 14/500
# 26/26 [==============================] - ETA: 0s - loss: 1.8175 - accuracy: 0.2847
# Epoch 14: val_accuracy did not improve from 0.17969
# 26/26 [==============================] - 7s 280ms/step - loss: 1.8175 - accuracy: 0.2847 - val_loss: 2.3204 - val_accuracy: 0.1615
# Epoch 15/500
# 26/26 [==============================] - ETA: 0s - loss: 1.7942 - accuracy: 0.3000
# Epoch 15: val_accuracy did not improve from 0.17969
# 26/26 [==============================] - 7s 281ms/step - loss: 1.7942 - accuracy: 0.3000 - val_loss: 2.3657 - val_accuracy: 0.1615
# Epoch 16/500
# 26/26 [==============================] - ETA: 0s - loss: 1.7750 - accuracy: 0.2997
# Epoch 16: val_accuracy did not improve from 0.17969
# 26/26 [==============================] - 7s 277ms/step - loss: 1.7750 - accuracy: 0.2997 - val_loss: 2.4541 - val_accuracy: 0.1641
# Epoch 17/500
# 26/26 [==============================] - ETA: 0s - loss: 1.7231 - accuracy: 0.3376
# Epoch 17: val_accuracy did not improve from 0.17969
# 26/26 [==============================] - 7s 278ms/step - loss: 1.7231 - accuracy: 0.3376 - val_loss: 2.2610 - val_accuracy: 0.1771
# Epoch 18/500
# 26/26 [==============================] - ETA: 0s - loss: 1.7084 - accuracy: 0.3450
# Epoch 18: val_accuracy improved from 0.17969 to 0.22135, saving model to /content/drive/My Drive/Colab Notebooks/input/model_weights.h5
# 26/26 [==============================] - 8s 322ms/step - loss: 1.7084 - accuracy: 0.3450 - val_loss: 2.3687 - val_accuracy: 0.2214
# Epoch 19/500
# 26/26 [==============================] - ETA: 0s - loss: 1.7038 - accuracy: 0.3422
# Epoch 19: val_accuracy did not improve from 0.22135
# 26/26 [==============================] - 7s 278ms/step - loss: 1.7038 - accuracy: 0.3422 - val_loss: 2.4776 - val_accuracy: 0.2109
# Epoch 20/500
# 26/26 [==============================] - ETA: 0s - loss: 1.6838 - accuracy: 0.3529
# Epoch 20: val_accuracy improved from 0.22135 to 0.27865, saving model to /content/drive/My Drive/Colab Notebooks/input/model_weights.h5
# 26/26 [==============================] - 8s 325ms/step - loss: 1.6838 - accuracy: 0.3529 - val_loss: 2.3945 - val_accuracy: 0.2786
# Epoch 21/500
# 26/26 [==============================] - ETA: 0s - loss: 1.6513 - accuracy: 0.3661
# Epoch 21: val_accuracy did not improve from 0.27865
# 26/26 [==============================] - 7s 277ms/step - loss: 1.6513 - accuracy: 0.3661 - val_loss: 2.2826 - val_accuracy: 0.2552
# Epoch 22/500
# 26/26 [==============================] - ETA: 0s - loss: 1.6297 - accuracy: 0.3667
# Epoch 22: val_accuracy did not improve from 0.27865
# 26/26 [==============================] - 7s 280ms/step - loss: 1.6297 - accuracy: 0.3667 - val_loss: 2.5876 - val_accuracy: 0.2344
# Epoch 23/500
# 26/26 [==============================] - ETA: 0s - loss: 1.6064 - accuracy: 0.3958
# Epoch 23: val_accuracy improved from 0.27865 to 0.29167, saving model to /content/drive/My Drive/Colab Notebooks/input/model_weights.h5
# 26/26 [==============================] - 9s 332ms/step - loss: 1.6064 - accuracy: 0.3958 - val_loss: 2.2770 - val_accuracy: 0.2917
# Epoch 24/500
# 26/26 [==============================] - ETA: 0s - loss: 1.5838 - accuracy: 0.3990
# Epoch 24: val_accuracy improved from 0.29167 to 0.30208, saving model to /content/drive/My Drive/Colab Notebooks/input/model_weights.h5
# 26/26 [==============================] - 8s 299ms/step - loss: 1.5838 - accuracy: 0.3990 - val_loss: 2.0837 - val_accuracy: 0.3021
# Epoch 25/500
# 26/26 [==============================] - ETA: 0s - loss: 1.5675 - accuracy: 0.3998
# Epoch 25: val_accuracy did not improve from 0.30208
# 26/26 [==============================] - 7s 279ms/step - loss: 1.5675 - accuracy: 0.3998 - val_loss: 2.1612 - val_accuracy: 0.3021
# Epoch 26/500
# 26/26 [==============================] - ETA: 0s - loss: 1.5490 - accuracy: 0.4102
# Epoch 26: val_accuracy did not improve from 0.30208
# 26/26 [==============================] - 7s 273ms/step - loss: 1.5490 - accuracy: 0.4102 - val_loss: 2.1242 - val_accuracy: 0.2865
# Epoch 27/500
# 26/26 [==============================] - ETA: 0s - loss: 1.5118 - accuracy: 0.4114
# Epoch 27: val_accuracy did not improve from 0.30208
# 26/26 [==============================] - 7s 277ms/step - loss: 1.5118 - accuracy: 0.4114 - val_loss: 2.1211 - val_accuracy: 0.2891
# Epoch 28/500
# 26/26 [==============================] - ETA: 0s - loss: 1.5156 - accuracy: 0.4273
# Epoch 28: val_accuracy improved from 0.30208 to 0.36198, saving model to /content/drive/My Drive/Colab Notebooks/input/model_weights.h5
# 26/26 [==============================] - 8s 323ms/step - loss: 1.5156 - accuracy: 0.4273 - val_loss: 1.7643 - val_accuracy: 0.3620
# Epoch 29/500
# 26/26 [==============================] - ETA: 0s - loss: 1.4874 - accuracy: 0.4362
# Epoch 29: val_accuracy improved from 0.36198 to 0.37760, saving model to /content/drive/My Drive/Colab Notebooks/input/model_weights.h5
# 26/26 [==============================] - 7s 285ms/step - loss: 1.4874 - accuracy: 0.4362 - val_loss: 1.6884 - val_accuracy: 0.3776
# Epoch 30/500
# 26/26 [==============================] - ETA: 0s - loss: 1.4805 - accuracy: 0.4444
# Epoch 30: val_accuracy did not improve from 0.37760
# 26/26 [==============================] - 7s 281ms/step - loss: 1.4805 - accuracy: 0.4444 - val_loss: 1.9446 - val_accuracy: 0.3516
# Epoch 31/500
# 26/26 [==============================] - ETA: 0s - loss: 1.4543 - accuracy: 0.4426
# Epoch 31: val_accuracy did not improve from 0.37760
# 26/26 [==============================] - 7s 282ms/step - loss: 1.4543 - accuracy: 0.4426 - val_loss: 1.8135 - val_accuracy: 0.3750
# Epoch 32/500
# 26/26 [==============================] - ETA: 0s - loss: 1.4276 - accuracy: 0.4665
# Epoch 32: val_accuracy did not improve from 0.37760
# 26/26 [==============================] - 7s 277ms/step - loss: 1.4276 - accuracy: 0.4665 - val_loss: 1.9573 - val_accuracy: 0.3672
# Epoch 33/500
# 26/26 [==============================] - ETA: 0s - loss: 1.4321 - accuracy: 0.4469
# Epoch 33: val_accuracy improved from 0.37760 to 0.39323, saving model to /content/drive/My Drive/Colab Notebooks/input/model_weights.h5
# 26/26 [==============================] - 8s 323ms/step - loss: 1.4321 - accuracy: 0.4469 - val_loss: 1.6800 - val_accuracy: 0.3932
# Epoch 34/500
# 26/26 [==============================] - ETA: 0s - loss: 1.4135 - accuracy: 0.4637
# Epoch 34: val_accuracy did not improve from 0.39323
# 26/26 [==============================] - 7s 281ms/step - loss: 1.4135 - accuracy: 0.4637 - val_loss: 1.6359 - val_accuracy: 0.3854
# Epoch 35/500
# 26/26 [==============================] - ETA: 0s - loss: 1.4190 - accuracy: 0.4405
# Epoch 35: val_accuracy did not improve from 0.39323
# 26/26 [==============================] - 7s 279ms/step - loss: 1.4190 - accuracy: 0.4405 - val_loss: 1.7290 - val_accuracy: 0.3776
# Epoch 36/500
# 26/26 [==============================] - ETA: 0s - loss: 1.3935 - accuracy: 0.4680
# Epoch 36: val_accuracy improved from 0.39323 to 0.41406, saving model to /content/drive/My Drive/Colab Notebooks/input/model_weights.h5
# 26/26 [==============================] - 9s 329ms/step - loss: 1.3935 - accuracy: 0.4680 - val_loss: 1.5716 - val_accuracy: 0.4141
# Epoch 37/500
# 26/26 [==============================] - ETA: 0s - loss: 1.3819 - accuracy: 0.4732
# Epoch 37: val_accuracy did not improve from 0.41406
# 26/26 [==============================] - 7s 275ms/step - loss: 1.3819 - accuracy: 0.4732 - val_loss: 1.6060 - val_accuracy: 0.4115
# Epoch 38/500
# 26/26 [==============================] - ETA: 0s - loss: 1.3873 - accuracy: 0.4695
# Epoch 38: val_accuracy improved from 0.41406 to 0.44010, saving model to /content/drive/My Drive/Colab Notebooks/input/model_weights.h5
# 26/26 [==============================] - 9s 333ms/step - loss: 1.3873 - accuracy: 0.4695 - val_loss: 1.5759 - val_accuracy: 0.4401
# Epoch 39/500
history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(1, len(acc) + 1)

    plt.figure(figsize = (24, 6))
    plt.subplot(1,2,1)
    plt.plot(epochs, acc, 'b', label = 'Training Accuracy')
    plt.plot(epochs, val_acc, 'r', label = 'Validation Accuracy')
    plt.grid(True)
    plt.legend()
    plt.xlabel('Epoch')
    


    plt.subplot(1,2,2)
    plt.plot(epochs, loss, 'b', label = 'Training Loss')
    plt.plot(epochs, val_loss, 'r', label = 'Validation Loss')
    plt.grid(True)
    plt.legend()
    plt.xlabel('Epoch')
    plt.show()
 
# print best epoch with best accuracy on validation

def get_best_epcoh(history):
    valid_acc = history.history['val_accuracy']
    best_epoch = valid_acc.index(max(valid_acc)) + 1
    best_acc =  max(valid_acc)
    print('Best Validation Accuracy Score {:0.5f}, is for epoch {}'.format( best_acc, best_epoch))
    return best_epoch

# %%
plot_results(history)
best_epoch =get_best_epcoh(history)
# Out:
# Best Validation Accuracy Score 0.53385, is for epoch 395

# %% [markdown]
# **OpenCV**

# %%
import numpy as np
import cv2
from tensorflow.keras.models import model_from_json

# %%
model_json_file = '/content/drive/My Drive/Colab Notebooks/input/model.json'
model_weights_file = '/content/drive/My Drive/Colab Notebooks/input/model_weights.h5'
with open(model_json_file, "r") as json_file:
    loaded_model_json = json_file.read()
    loaded_model = model_from_json(loaded_model_json)
    loaded_model.load_weights(model_weights_file)

# %%
face_cascade = cv2.CascadeClassifier('/content/drive/My Drive/Colab Notebooks/input/haarcascade_frontalface_default.xml')

# %%
# !sudo apt-get install ffmpeg
# !pip install opencv-contrib-python
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ffmpeg is already the newest version (7:3.4.11-0ubuntu0.1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 20 not upgraded.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.8/dist-packages (4.6.0.66)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.8/dist-packages (from opencv-contrib-python) (1.21.6)

# %%
import os
os.environ["OPENCV_FFMPEG_CAPTURE_OPTIONS"] = "rtsp_transport;udp"

from google.colab.patches import cv2_imshow

# cap = cv2.VideoCapture('/content/drive/My Drive/Colab Notebooks/images/train/angry/1 angry.jpg')



# cap = cv2.VideoCapture(0)
cap = cv2.VideoCapture('/content/drive/My Drive/Colab Notebooks/TEST.mp4')
print(f"WebCam: {cap.isOpened()}")
import copy


import time
while not cap.isOpened():
  time.sleep(1)
  print("waiting for cam")



while True:
    

    ret, frame = cap.read()
    print(ret)
    img = copy.deepcopy(frame)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    # gray = cv2.cvtColor(img, cv2.IMREAD_GRAYSCALE)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        fc = gray[y:y+h, x:x+w]
        
        roi = cv2.resize(fc, (48,48))
        pred = loaded_model.predict(roi[np.newaxis, :, :, np.newaxis])
        text_idx=np.argmax(pred)
        text_list = ['Angry', 'Disgust', 'Fear', 'Happy', 'Neutral', 'Sad', 'Surprise']
        
        confidence = round(pred[0][np.argmax(pred)]*100,1)
        text = f"{text_list[text_idx]}: {confidence}%"

        cv2.putText(img, text, (x, y-5),
           cv2.FONT_HERSHEY_SIMPLEX, 0.45, (255, 0, 255), 2)
        img = cv2.rectangle(img, (x,y), (x+w, y+h), (0,0,255), 2)
            
    
    # cv2.imshow("frame", img)
    cv2_imshow(img)
    key = cv2.waitKey(1) & 0xFF
    if key== ord('q'):
        break
    
cap.release()
cv2.destroyAllWindows()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode

def take_photo(filename='photo.jpg', quality=0.8):
  js = Javascript('''
    async function takePhoto(quality) {
      const div = document.createElement('div');
      const capture = document.createElement('button');
      capture.textContent = 'Capture';
      div.appendChild(capture);

      const video = document.createElement('video');
      video.style.display = 'block';
      const stream = await navigator.mediaDevices.getUserMedia({video: true});

      document.body.appendChild(div);
      div.appendChild(video);
      video.srcObject = stream;
      await video.play();

      // Resize the output to fit the video element.
      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      // Wait for Capture to be clicked.
      await new Promise((resolve) => capture.onclick = resolve);

      const canvas = document.createElement('canvas');
      canvas.width = video.videoWidth;
      canvas.height = video.videoHeight;
      canvas.getContext('2d').drawImage(video, 0, 0);
      stream.getVideoTracks()[0].stop();
      div.remove();
      return canvas.toDataURL('image/jpeg', quality);
    }
    ''')
  display(js)
  data = eval_js('takePhoto({})'.format(quality))
  binary = b64decode(data.split(',')[1])
  with open(filename, 'wb') as f:
    f.write(binary)
  return filename

# %%
from IPython.display import Image
try:
  filename = take_photo()
  print('Saved to {}'.format(filename))
  
  # Show the image which was just taken.
  display(Image(filename))
except Exception as err:
  # Errors will be thrown if the user does not have a webcam or if they do not
  # grant the page permission to access it.
  print(str(err))
# Out:
# NotReadableError: Could not start video source
